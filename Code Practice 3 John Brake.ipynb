# %%
import pandas as pd

data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}

weo = pd.DataFrame(data)

# %% [markdown]
# ### Question 1 a

# %% [markdown]
# The import statement imports the pandas package and allows us to call the package using the pd. command

# %% [markdown]
# ### Question 1 b

# %% [markdown]
# The data object is a dictionary

# %% [markdown]
# ### Question 1 c

# %% [markdown]
# Because the Dataframe function is part of the pandas package, which we call using pd.

# %% [markdown]
# ### Question 1 d

# %% [markdown]
# weo is a dataframe

# %% [markdown]
# ### Question 1 e

# %% [markdown]
# weo has 4 columns and 7 rows

# %%
weo.shape
# Out:
# (7, 4)

# %% [markdown]
# ### Question 1 f

# %%
weo.dtypes
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# Year      int64
# dtype: object

# %% [markdown]
# The columns BRA, JPN, and USA have float datatypes, while Year has an int datatype.

# %% [markdown]
# ### Question 1 g

# %%
print(type(weo['Year']),
type(weo[['Year']]))
# Out:
# <class 'pandas.core.series.Series'> <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# weo['Year'] is series type, while weo[['Year']] is a dataframe weo[[3]] outputs an error. These expressions output either a series or a sub-dataframe from the data frame depending on the amount of square brackets.

# %%
weo['Year']
weo[['Year']]
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %% [markdown]
# ### Question 1 h

# %%
weo['Year'].astype(float)
# Out:
# 0    2008.0
# 1    2009.0
# 2    2010.0
# 3    2011.0
# 4    2012.0
# 5    2013.0
# 6    2014.0
# Name: Year, dtype: float64

# %% [markdown]
# ### Question 1 i

# %%
t = weo.tail(3)
type(t)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# This statement takes that last 3 rows of the dataframe weo and sets it to t, which is also a dataframe, it looks like a 4 X 3 dataframe

# %%
t
# Out:
#      BRA    JPN    USA  Year
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# ### Question 1 j

# %%
s= weo.head(3)

# %% [markdown]
# ### Question 1 k

# %%
type( weo['BRA'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# This is a series

# %% [markdown]
# ### Question 1 l

# %%
weo["NewGDP"]=weo.BRA/weo.JPN

# %%
weo
# Out:
#      BRA    JPN    USA  Year    NewGDP
# 0  13.37  33.43  48.30  2008  0.399940
# 1  13.30  31.83  46.91  2009  0.417845
# 2  14.34  33.71  48.31  2010  0.425393
# 3  15.07  34.29  49.72  2011  0.439487
# 4  15.46  35.60  51.41  2012  0.434270
# 5  15.98  36.79  52.94  2013  0.434357
# 6  16.10  37.39  54.60  2014  0.430596

# %%
drop()?
# Out:
#   File "<ipython-input-103-453e45d48807>", line 1
#     drop()?
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Question 1 m

# %%
weo.drop(["NewGDP"],axis=1,inplace=True)

# %%
weo
# Out:
#       Brazil  Japan  United States
# Year
# 2008   13.37  33.43          48.30
# 2009   13.30  31.83          46.91
# 2010   14.34  33.71          48.31
# 2011   15.07  34.29          49.72
# 2012   15.46  35.60          51.41
# 2013   15.98  36.79          52.94
# 2014   16.10  37.39          54.60

# %% [markdown]
# ### Question 1 n

# %%
print(weo.columns)
# Out:
# Index(['BRA', 'JPN', 'USA', 'Year', 'NewGDP'], dtype='object')

# %% [markdown]
# The row labels are 1 - 6

# %% [markdown]
# ### Question 1 o

# %%
weo.set_index(["Year"],inplace=True)

# %% [markdown]
# ### Question 1 p

# %%
weo.columns=["Brazil","Japan","United States"]

# %%
weo
# Out:
#       Brazil  Japan  United States
# Year
# 2008   13.37  33.43          48.30
# 2009   13.30  31.83          46.91
# 2010   14.34  33.71          48.31
# 2011   15.07  34.29          49.72
# 2012   15.46  35.60          51.41
# 2013   15.98  36.79          52.94
# 2014   16.10  37.39          54.60

# %% [markdown]
# ### Question 1 q

# %%
from pandas import ExcelWriter

writer = ExcelWriter('CodePractice3.xlsx')
weo.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# ### Question 1 r

# %%
weo.describe()
# Out:
#           Brazil      Japan  United States
# count   7.000000   7.000000       7.000000
# mean   14.802857  34.720000      50.312857
# std     1.161704   1.975238       2.783258
# min    13.300000  31.830000      46.910000
# 25%    13.855000  33.570000      48.305000
# 50%    15.070000  34.290000      49.720000
# 75%    15.720000  36.195000      52.175000
# max    16.100000  37.390000      54.600000

# %% [markdown]
# ### Question 1 s

# %%
weo.mean(axis=1)
# Out:
# Year
# 2008    31.700000
# 2009    30.680000
# 2010    32.120000
# 2011    33.026667
# 2012    34.156667
# 2013    35.236667
# 2014    36.030000
# dtype: float64

# %% [markdown]
# ### Question 1 t

# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
weo.plot(figsize=(20,8),fontsize=12,colormap='tab20b')
plt.suptitle("Countries' GDP (2008-2014)",fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.show()

# %% [markdown]
# ### Question 1 u

# %%
weo.plot(figsize=(20,8),fontsize=12,color = ["green","red","blue"])

# %% [markdown]
# ### Question 1 v

# %%
weo.plot(figsize=(20,8),fontsize=12,color = ["green","red","blue"]).set_yscale('log')

# %% [markdown]
# ### Question 1 w

# %%
weo.plot(figsize=(20,8),fontsize=12,color = ["green","red","blue"]).set_yscale('log')

# %%
weo["Brazil"].plot()

# %% [markdown]
# ### Question 2 a

# %%
import os
url = "https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv"
ep = pd.read_csv(url)

# %% [markdown]
# ### Question 2 b

# %%
ep
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %%
ep.dtypes
# Out:
# TimeStamp                                                                                              object
# Why have you enrolled in this course?                                                                  object
# What program are you enrolled in?                                                                      object
# How much programming experience have you had?                                                          object
# How much experience with probability and statistics have you had?                                      object
# What is your expected major or concentration?                                                          object
# What career path most interests you?                                                                   object
# Do you use social media for information purposes?  Check all that apply.                               object
# ...

# %% [markdown]
# Its contents are a data frame with students responses to the survey, the variables are questions, the responses are the data

# %% [markdown]
# ### Question 2 c

# %% [markdown]
# The contents are a data frame with object responces, the variables are objects

# %% [markdown]
# ### Question 2 d

# %%
ep.columns=['Time','Why','Program','Prog Exp','Stat Exp','Major','Career','Social Media Use','Data Interests','Special Topics']

# %%
ep
# Out:
#                    Time                                                Why  \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# ### Question 2 e

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# Recommended by a professor.                           1
# I code/build websites in my spare time as a hobby     1
# I like a challenge                                    1
# To finish my major                                    1
# i am living in Santiago de Chile                      1
# Wanted to try something completely different          1
# Name: Why, dtype: int64

# %%
[list(ep)[1]]
# Out:
# ['Why']

# %% [markdown]
# The code selects the 'why' column by converting ep to a list and selecting the second item and then in sorts the value counts using the value_counts sort method.

# %% [markdown]
# ### Question 3 a

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2
df538 = pd.read_csv(url)

# %%
df538.shape
# Out:
# (173, 21)

# %% [markdown]
# ### Question 3 b

# %%
df538.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %% [markdown]
# ### Question 3 c

# %%
crylist = [2, 4, 15, 16, 17]
for i in crylist:
    print(list(df538)[i])
# Out:
# Major
# Men
# Median
# P25th
# P75th

# %% [markdown]
# Major represents the major, men represents male graduates, median is median earnings, P25th is the 25th percentile of earnings, P75th is the 75th percentile of earnings

# %% [markdown]
# ### Question 3 d

# %%
df538.set_index(["Major"])
# Out:
#                                                Rank  Major_code     Total  \
# Major
# PETROLEUM ENGINEERING                             1        2419    2339.0
# MINING AND MINERAL ENGINEERING                    2        2416     756.0
# METALLURGICAL ENGINEERING                         3        2415     856.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING         4        2417    1258.0
# CHEMICAL ENGINEERING                              5        2405   32260.0
# NUCLEAR ENGINEERING                               6        2418    2573.0
# ACTUARIAL SCIENCE                                 7        6202    3777.0
# ASTRONOMY AND ASTROPHYSICS                        8        5001    1792.0
# MECHANICAL ENGINEERING                            9        2414   91227.0
# ELECTRICAL ENGINEERING                           10        2408   81527.0
# COMPUTER ENGINEERING                             11        2407   41542.0
# AEROSPACE ENGINEERING                            12        2401   15058.0
# ...

# %% [markdown]
# ### Question 3 e

# %%
df538new=df538["Total"].sort_values(ascending=False)

# %%
df538new.head(10)
# Out:
# 145    393735.0
# 76     329927.0
# 123    280709.0
# 57     234590.0
# 93     213996.0
# 34     209394.0
# 77     205211.0
# 40     198633.0
# 137    194673.0
# 78     182621.0
# Name: Total, dtype: float64

# %% [markdown]
# ### Question 3 f

# %%
newdict=dict(df538new.head(10))
for key in newdict.keys():
    print(list(df538["Major"])[key])
# Out:
# PSYCHOLOGY
# BUSINESS MANAGEMENT AND ADMINISTRATION
# BIOLOGY
# GENERAL BUSINESS
# COMMUNICATIONS
# NURSING
# MARKETING AND MARKETING RESEARCH
# ACCOUNTING
# ENGLISH LANGUAGE AND LITERATURE
# POLITICAL SCIENCE AND GOVERNMENT

# %% [markdown]
# ### Question 3 g

# %%
df538.set_index(['Major'],inplace=True)

# %%
df538['Median'].sort_values()[:10].plot(kind = 'barh')

# %%
df538['P25th'].sort_values()[:10].plot(kind = 'barh')
